# %% [markdown]
# ## Exercício 01 - Escreva um programa Python para desenhar uma linha com rótulo
#
# adequado no eixo x, eixo y e um título.
# Amostra de dados:
#
# x = range(1,50)
#
# y = [value * 3 for value in x]

# %%
import matplotlib.pyplot

# %%
from matplotlib import pyplot as plt


x = range(1,50)
y = [ value * 3 for value in x]

print('Valores de X')
print(range(1,50))
print('Valores de Y (Três vezes X)')
print(y)

plt.plot(x,y)
plt.title('Draw a line')
plt.ylabel('y - axis')
plt.xlabel('x-axis')
# Out:
# Valores de X
# range(1, 50)
# Valores de Y (Três vezes X)
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# Text(0.5, 0, 'x-axis')

# %% [markdown]
# ### Exercício 02 - Escreva um programa Python para desenhar uma linha usando
#
# determinados valores de eixo com rótulo adequado no eixo x, eixo y e um título.
# Amostra de dados:
#
#  x axis values
#
# x = [1,2,3]
#
#  y axis values
#
# y = [2,4,1]
#
# O trecho de código fornece a saída mostrada na captura de tela a seguir

# %%
x = [1,2,3]
y = [2,4,1]

plt.plot(x,y)
plt.title('Sample graph!')
plt.ylabel('y-axis')
plt.xlabel('x-axis')
# Out:
# Text(0.5, 0, 'x-axis')

# %% [markdown]
# ## Exercício 03 - Escreva um programa Python para desenhar uma linha usando
#
# determinados valores de eixo retirados de um arquivo de texto, com rótulo
# adequado no eixo x, eixo y e um título.
#
# Dados de teste:
#
# X,Y
#
# 1,2
#
# 3,4
#
# 3,1
#
# O trecho de código fornece a saída mostrada na captura de tela a seguir:

# %% [markdown]
# ### Exercício 04 - Escreva um programa Python para desenhar gráficos de
# linhas dos dados financeiros da Alphabet Inc. entre 3 de outubro de 2016
# a 7 de outubro de 2016.
#
# Exemplo de dados estão no arquivo fdata.csv.
#
# O trecho de código fornece a saída mostrada na captura de tela a seguir:

# %%
from stat import filemode
import pandas as pd
import matplotlib.pyplot as plt


path = 'C:\\Users\\FIC\\Documents\\Henrique-Rodrigues\\016 - Python -  Fundamentos de Big Data e Data Analytics-20230925T214902Z-001\\016 - Python -  Fundamentos de Big Data e Data Analytics\\003 - Arquivos\\'
file = 'fdata.csv'


# O argumento index_col permite selecionar qual coluna será
# O indice do dataframe exemplo: 0 - primeira coluna como indice
# 1 - segunda coluna como indice e none - padrão
df = pd.read_csv(path + file, sep=',', index_col=None)
df.columns = ['data','abertura','alta','baixa','fechamento']

df.head()
# Out:
#         data    abertura          alta          baixa  fechamento
# 0  10-03 -16     774. 25    776.065002     769.500000  772.559998
# 1   10-04-16  776.030029    778.710022     772.890015  776.429993
# 2   10-05-16  779.309998    782.070007     775.650024  776.469971
# 3   10-06-16     779.780  47998.775000  539978.000000  776.859985
# 4   10-07-16  779.659973    779.659973     770.757700    5.080017

# %%
df.plot()
# Out:
# <Axes: >

# %%
df_2 = df[['data', 'abertura']]

df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   data      5 non-null      object
#  1   abertura  5 non-null      object
# dtypes: object(2)
# memory usage: 208.0+ bytes

# %%
# Converter em numerico pd.to_numeric(coluna)

df_2['abertura'] = df_2['abertura'].replace('774. 25', '774.25')
df_2['abertura']
df_2['abertura'] = pd.to_numeric(df_2['abertura'])

df_2.plot()

x = df_2['data']
y = df_2['abertura']

plt.plot(x,y)
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_16344\2553923872.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['abertura'] = df_2['abertura'].replace('774. 25', '774.25')
# C:\Users\FIC\AppData\Local\Temp\ipykernel_16344\2553923872.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['abertura'] = pd.to_numeric(df_2['abertura'])

# %%
df_3 = df[['data', 'alta']]
df_3['alta'] = pd.to_numeric(df_3['alta'])

y_2 = df['alta']

plt.plot(x, y_2)
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_16344\3552735028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3['alta'] = pd.to_numeric(df_3['alta'])

# %%
df_4 = df[['data', 'baixa']]
df_4['baixa'] = pd.to_numeric(df_4['baixa'])

y_3 = df['baixa']

plt.plot(x, y_3)
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_16344\1558916002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4['baixa'] = pd.to_numeric(df_4['baixa'])

# %%
df_5 = df[['data', 'fechamento']]
df_5['fechamento'] = pd.to_numeric(df_5['fechamento'])

y_4 = df['fechamento']

plt.plot(x, y_4)
# Out:
# C:\Users\FIC\AppData\Local\Temp\ipykernel_16344\3217555321.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_5['fechamento'] = pd.to_numeric(df_5['fechamento'])
