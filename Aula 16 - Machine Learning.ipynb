# %% [markdown]
# ### importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# mapeamento do caminho e arquivo 
path = 'C:\\Users\\FIC\\Documents\\Henrique-Rodrigues\\Aquivo atualizado\\017 - Python - Fundamentos de Big Data e Data Analytics\\002 - Exercícios\\Machine Learning-20231006T223445Z-001\\Machine Learning\\'
file = 'IceCreamData.csv'

# Atribuir o arquivo a um dataframe
iceCream = pd.read_csv(path + file)

# Verificar o cabeçalho
iceCream.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %% [markdown]
# ### Vilualizar o cabeçalho e o final do dataframe

# %%
# Visualizar as primeiras linhas do DataFrame
iceCream.head(2)
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122

# %%
# VIsualizar as últimas linhas do DataFrame
iceCream.tail(2)
# Out:
#      Temperature     Revenue
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
iceCream.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
iceCream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %% [markdown]
# ### Visualizar os dados do Dataset

# %%
### Grafico de dispersão e histograma
sns.jointplot(x = 'Temperature', y = 'Revenue', data = iceCream, color = 'green')
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(iceCream)
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ### Grafico de dispersão

# %%
sns.lmplot(x = 'Temperature',
           y = 'Revenue',
           data = iceCream)

# %% [markdown]
# ## passo 04 - Criando

# %%
x = iceCream[['Temperature']]
y = iceCream['Revenue']

# %% [markdown]
# ### Passo 5 - modelo treino
# Importar a biblioteca Scikit Learn e dividir as bases em treino e teste, sendo que o tamanho do teste será de 25%

# %%
# importando o comando train_test_split para dividir o DataFrame
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.25)

# %%
X_train.shape
# Out:
# (375, 1)

# %%
X_test.shape
# Out:
# (125, 1)

# %%
y_train.shape
# Out:
# (375,)

# %%
y_test.shape
# Out:
# (125,)

# %% [markdown]
# ### Importar o algoritimo LinearRegression da biblioteca ScikitLearn

# %%
from sklearn.linear_model import LinearRegression

# %%
# Este comando irá gerar a linha de tendencia
# E calcular os coeficientes linear e angular
regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coeficiente angular (a):', regressor.coef_)
print('Coeficiente linear (b):', regressor.intercept_)
# Out:
# Coeficiente angular (a): [21.51363301]
# Coeficiente linear (b): 43.69807097123112

# %% [markdown]
# ### Passo 06: executar o teste

# %%
y_previsao = regressor.predict(X_test)

y_previsao
# Out:
# array([531.5962901 , 430.79330468, 386.12363629, 581.59009172,
#        352.6644796 , 804.41498354, 395.76749168, 556.25870728,
#        656.08219226, 661.78291303, 420.55397173, 304.50814533,
#        196.60602412, 525.55993429, 295.2900626 , 622.92264109,
#        232.89547698, 547.64733374, 572.22100652, 600.16848252,
#        461.7782589 , 607.17600784, 547.27320714, 486.77855091,
#        875.59158819, 353.05759456, 729.7994053 , 317.0227059 ,
#        636.89262389, 643.65113966, 547.38703211, 668.36229898,
#        863.29452959, 664.70175819, 570.64174709, 184.45132466,
#        670.37143586, 356.74751027, 368.94540458, 621.87594562,
#        473.4859711 , 122.53842735, 391.05340591, 659.71368921,
#        592.28890898, 465.74984401, 292.60313892, 474.32321866,
#        626.04215617, 725.02330949, 614.4594612 , 494.36379364,
#        747.54627804, 611.00712721, 715.54706833, 495.63593026,
#        399.91968674, 267.51348832, 409.38441532,  43.69807097,
#        430.87924283, 559.24817997, 450.48835652, 451.98360758,
#        329.86803599, 528.33029149, 833.303738  , 470.04534052,
#        291.1800975 , 751.34798311, 393.48222215, 758.71812738,
#        453.73256677, 535.72694873, 504.6181444 , 577.63962698,
#        237.72652024, 478.84185781, 646.06306791, 627.35028144,
#        380.63306628, 776.48841213, 559.14991172, 181.25268265,
#        520.6811068 , 440.40906843, 639.7345477 , 591.18216702,
#        623.35361015, 632.64240174, 571.25208219, 321.26208711,
#        603.16420967, 379.05390065, 451.99025766, 682.74296347,
#        559.69483204, 494.07753733, 377.61465129, 417.19048753,
#        621.84654294, 893.76958231, 446.18535906, 465.85275297,
#        696.21369552, 674.30595169, 452.14031374, 254.80082011,
#        590.559604  , 428.17248917, 458.21813537, 415.0703005 ,
#        524.79458873, 573.54898006, 674.1559296 , 314.15700457,
#        498.26232512, 651.73424357, 709.8695782 , 458.4523388 ,
#        510.62894805, 392.03170373, 672.1051563 , 652.50569728,
#        479.29203875])

# %%
plt.scatter(X_train,y_train, color = 'green')
plt.plot(X_train, regressor.predict(X_train), color = 'red')
plt.ylabel('Receita [Dólares]')
plt.xlabel('Temperatura [°C]')
plt.title('Receita gerada vs. Temperatura (Vendas de Sorvete)')
# Out:
# Text(0.5, 1.0, 'Receita gerada vs. Temperatura (Vendas de Sorvete)')
